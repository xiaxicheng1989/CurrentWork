# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
# Out:
# C:\Users\X\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
files=os.listdir("20200924")
datafile = [i for i in files if "txt" in i]

# %%
def getData(timeStr):
    return np.array([float(i[1]) 
                      for i in list(
                          pd.read_table('20200924/'+timeStr+'_RabiFlop_Counter.txt').iloc[14:-2].iloc[:,0].index)])

# %%
datafile
# Out:
# ['1101_RabiFlop_Counter.txt',
#  '1102_RabiFlop_Counter.txt',
#  '1103_RabiFlop_Counter.txt',
#  '1106_RabiFlop_Counter.txt',
#  '1108_RabiFlop_Counter.txt',
#  '1109_RabiFlop_Counter.txt',
#  '1111_RabiFlop_Counter.txt',
#  '1115_RabiFlop_Counter.txt',
#  '1116_RabiFlop_Counter.txt',
#  '1130_RabiFlop_Counter.txt',
#  '1140_RabiFlop_Counter.txt',
#  '1201_RabiFlop_Counter.txt',
#  '1210_RabiFlop_Counter.txt',
#  '1211_RabiFlop_Counter.txt',
#  '1212_RabiFlop_Counter.txt',
#  '1213_RabiFlop_Counter.txt',
#  '1214_RabiFlop_Counter.txt',
#  '1215_RabiFlop_Counter.txt',
#  '1216_RabiFlop_Counter.txt',
#  '1217_RabiFlop_Counter.txt',
#  '1218_RabiFlop_Counter.txt',
#  '1219_RabiFlop_Counter.txt',
#  '1220_RabiFlop_Counter.txt',
#  '1221_RabiFlop_Counter.txt',
#  '1222_RabiFlop_Counter.txt',
#  '1223_RabiFlop_Counter.txt',
#  '1224_RabiFlop_Counter.txt',
#  '1225_RabiFlop_Counter.txt',
#  '1226_RabiFlop_Counter.txt',
#  '1227_RabiFlop_Counter.txt',
#  '1228_RabiFlop_Counter.txt',
#  '1229_RabiFlop_Counter.txt',
#  '1230_RabiFlop_Counter.txt',
#  '1231_RabiFlop_Counter.txt',
#  '1232_RabiFlop_Counter.txt',
#  '1233_RabiFlop_Counter.txt',
#  '1234_RabiFlop_Counter.txt',
#  '1235_RabiFlop_Counter.txt',
#  '1237_RabiFlop_Counter.txt',
#  '1238_RabiFlop_Counter.txt',
#  '1239_RabiFlop_Counter.txt',
#  '1240_RabiFlop_Counter.txt',
#  '1241_RabiFlop_Counter.txt',
#  '1242_RabiFlop_Counter.txt',
#  '1243_RabiFlop_Counter.txt',
#  '1244_RabiFlop_Counter.txt',
#  '1245_RabiFlop_Counter.txt',
#  '1246_RabiFlop_Counter.txt',
#  '1247_RabiFlop_Counter.txt',
#  '1248_RabiFlop_Counter.txt',
#  '1249_RabiFlop_Counter.txt',
#  '1250_RabiFlop_Counter.txt',
#  '1251_RabiFlop_Counter.txt',
#  '1252_RabiFlop_Counter.txt',
#  '1253_RabiFlop_Counter.txt',
#  '1254_RabiFlop_Counter.txt',
#  '1255_RabiFlop_Counter.txt',
#  '1256_RabiFlop_Counter.txt',
#  '1257_RabiFlop_Counter.txt',
#  '1258_RabiFlop_Counter.txt',
#  '1259_RabiFlop_Counter.txt',
#  '1300_RabiFlop_Counter.txt',
#  '1301_RabiFlop_Counter.txt',
#  '1302_RabiFlop_Counter.txt',
#  '1303_RabiFlop_Counter.txt',
#  '1304_RabiFlop_Counter.txt',
#  '1305_RabiFlop_Counter.txt',
#  '1306_RabiFlop_Counter.txt',
#  '1307_RabiFlop_Counter.txt',
#  '1308_RabiFlop_Counter.txt',
#  '1309_RabiFlop_Counter.txt',
#  '1310_RabiFlop_Counter.txt',
#  '1311_RabiFlop_Counter.txt',
#  '1312_RabiFlop_Counter.txt',
#  '1313_RabiFlop_Counter.txt',
#  '1314_RabiFlop_Counter.txt',
#  '1315_RabiFlop_Counter.txt',
#  '1316_RabiFlop_Counter.txt',
#  '1317_RabiFlop_Counter.txt',
#  '1318_RabiFlop_Counter.txt',
#  '1319_RabiFlop_Counter.txt',
#  '1321_RabiFlop_Counter.txt',
#  '1322_RabiFlop_Counter.txt',
#  '1323_RabiFlop_Counter.txt',
#  '1324_RabiFlop_Counter.txt',
#  '1325_RabiFlop_Counter.txt',
#  '1326_RabiFlop_Counter.txt',
#  '1327_RabiFlop_Counter.txt',
#  '1328_RabiFlop_Counter.txt',
#  '1329_RabiFlop_Counter.txt',
#  '1330_RabiFlop_Counter.txt',
#  '1331_RabiFlop_Counter.txt',
#  '1332_RabiFlop_Counter.txt',
#  '1333_RabiFlop_Counter.txt',
#  '1334_RabiFlop_Counter.txt',
#  '1335_RabiFlop_Counter.txt',
#  '1336_RabiFlop_Counter.txt',
#  '1337_RabiFlop_Counter.txt',
#  '1338_RabiFlop_Counter.txt',
#  '1339_RabiFlop_Counter.txt',
#  '1340_RabiFlop_Counter.txt',
#  '1341_RabiFlop_Counter.txt',
#  '1342_RabiFlop_Counter.txt',
#  '1343_RabiFlop_Counter.txt',
#  '1344_RabiFlop_Counter.txt',
#  '1345_RabiFlop_Counter.txt',
#  '1346_RabiFlop_Counter.txt',
#  '1347_RabiFlop_Counter.txt',
#  '1348_RabiFlop_Counter.txt',
#  '1349_RabiFlop_Counter.txt',
#  '1350_RabiFlop_Counter.txt',
#  '1351_RabiFlop_Counter.txt',
#  '1352_RabiFlop_Counter.txt',
#  '1353_RabiFlop_Counter.txt',
#  '1354_RabiFlop_Counter.txt',
#  '1355_RabiFlop_Counter.txt',
#  '1356_RabiFlop_Counter.txt',
#  '1357_RabiFlop_Counter.txt',
#  '1358_RabiFlop_Counter.txt',
#  '1359_RabiFlop_Counter.txt',
#  '1400_RabiFlop_Counter.txt',
#  '1401_RabiFlop_Counter.txt',
#  '1402_RabiFlop_Counter.txt',
#  '1403_RabiFlop_Counter.txt',
#  '1405_RabiFlop_Counter.txt',
#  '1406_RabiFlop_Counter.txt',
#  '1407_RabiFlop_Counter.txt',
#  '1408_RabiFlop_Counter.txt',
#  '1409_RabiFlop_Counter.txt',
#  '1410_RabiFlop_Counter.txt',
#  '1411_RabiFlop_Counter.txt',
#  '1412_RabiFlop_Counter.txt',
#  '1413_RabiFlop_Counter.txt',
#  '1414_RabiFlop_Counter.txt',
#  '1415_RabiFlop_Counter.txt',
#  '1449_RabiFlop_Counter.txt',
#  '1504_RabiFlop_Counter.txt',
#  '1519_RabiFlop_Counter.txt',
#  '1529_RabiFlop_Counter.txt',
#  '1539_RabiFlop_Counter.txt',
#  '1548_RabiFlop_Counter.txt',
#  '1552_RabiFlop_Counter.txt',
#  '1607_RabiFlop_Counter.txt',
#  '1617_RabiFlop_Counter.txt',
#  '1623_RabiFlop_Counter.txt',
#  '1629_RabiFlop_Counter.txt',
#  '1635_RabiFlop_Counter.txt',
#  '1639_RabiFlop_Counter.txt',
#  '1642_RabiFlop_Counter.txt',
#  '1646_RabiFlop_Counter.txt']

# %%
random_No = getData('1642')
random_With = getData('1646')

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(random_No)
ax.plot(random_With)
ax.legend(["No Compensation","With Compensation"])
ax.set_title("Random movement within the range")
ax.set_xlabel("Shots")
ax.set_ylabel("P2")
# Out:
# Text(0, 0.5, 'P2')

# %%
rotTrack_No = getData('1635')
rotTrack_With = getData('1639')

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(rotTrack_No)
ax.plot(rotTrack_With)
ax.legend(["No Compensation","With Compensation"])
ax.set_title("180$^\circ$ rotation")
ax.set_xlabel("Shots")
ax.set_ylabel("P2")

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
textstr = '\n'.join((
    r'$\Delta B_1$ = -100 mG',
    r'$\Delta B_2$ = -50 mG',
    r'$\Delta B_3$ = 80 mG',
    r'$\Delta B_4$ = 100 mG',
    r'$\Delta B_5$ = 0 mG',
    r'$\Delta B_6$ = -80 mG',))

ax.text(1.1, 0.75, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
# Out:
# Text(1.1, 0.75, '$\\Delta B_1$ = -100 mG\n$\\Delta B_2$ = -50 mG\n$\\Delta B_3$ = 80 mG\n$\\Delta B_4$ = 100 mG\n$\\Delta B_5$ = 0 mG\n$\\Delta B_6$ = -80 mG')

# %%
linrotlinTrack_No = getData('1623')
linrotlinTrack_With = getData('1629')

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(linrotlinTrack_No)
ax.plot(linrotlinTrack_With)
ax.legend(["No Compensation","With Compensation"])
ax.set_title("Linear movement: 0.5 m -> 90$^\circ$ rotation -> Linear movement back")
ax.set_xlabel("Shots")
ax.set_ylabel("P2")

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
textstr = '\n'.join((
    r'$\Delta B_1$ = 12 - -90 - 50 mG',
    r'$\Delta B_2$ = 50 - -1 - -50 mG',
    r'$\Delta B_3$ = 30 - 100 - -10 mG',
    r'$\Delta B_4$ = -20 - 50 - -30 mG',
    r'$\Delta B_5$ = -10 - 30 - -15 mG',
    r'$\Delta B_6$ = -10 - -90 - 40 mG',))

ax.text(1.1, 0.75, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
# Out:
# Text(1.1, 0.75, '$\\Delta B_1$ = 12 - -90 - 50 mG\n$\\Delta B_2$ = 50 - -1 - -50 mG\n$\\Delta B_3$ = 30 - 100 - -10 mG\n$\\Delta B_4$ = -20 - 50 - -30 mG\n$\\Delta B_5$ = -10 - 30 - -15 mG\n$\\Delta B_6$ = -10 - -90 - 40 mG')

# %%
linTrack_No = getData('1607')
linTrack_With = getData('1617')

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(linTrack_No)
ax.plot(linTrack_With)
ax.legend(["No Compensation","With Compensation"])
ax.set_title("Linear movement: 1 m ")
ax.set_xlabel("Shots")
ax.set_ylabel("P2")

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
textstr = '\n'.join((
    r'$\Delta B_1$ = 6 mG',
    r'$\Delta B_2$ = 70 mG',
    r'$\Delta B_3$ = 40 mG',
    r'$\Delta B_4$ = -40 mG',
    r'$\Delta B_5$ = -20 mG',
    r'$\Delta B_6$ = -30 mG',))

ax.text(1.1, 0.75, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
# Out:
# Text(1.1, 0.75, '$\\Delta B_1$ = 6 mG\n$\\Delta B_2$ = 70 mG\n$\\Delta B_3$ = 40 mG\n$\\Delta B_4$ = -40 mG\n$\\Delta B_5$ = -20 mG\n$\\Delta B_6$ = -30 mG')
